# %%
def main():
  print("Welcome to Agreement Bot")
  Fav_Anm:str = input("What's your favourite animal? ")
  print(f"My Favourite animal is also {Fav_Anm}!")

if __name__ == '__main__':
    main()
# Out:
# Welcome to Agreement Bot
# What's Your favourite animal? cow
# My Favourite animal is also cow!
