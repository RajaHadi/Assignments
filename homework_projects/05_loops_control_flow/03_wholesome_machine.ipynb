# %% [markdown]
# # **Problem Statement**
# Write a program which prompts the user to type an affirmation of your choice (we'll use "I am capable of doing anything I put my mind to.") until they type it correctly. Sometimes, especially in the midst of such uncertain times, we just need to be reminded that we are resilient, capable, and strong; this little Python program may be able to help!

# %% [markdown]
# # ***Solution:***

# %%
affirm:str="I am capable of doing anything I put my mind to"

def main():

  user_inp:str=input(f"please write the follwing affirmation = {affirm}")
  while user_inp != affirm :
    print("That wasn't affirmation")
    print(f"Please write the following affirmation = {affirm}")
    user_inp= input()

  print("Yes, Thats right!")

if __name__ == '__main__':
    main()
# Out:
# please write the follwing affirmation = I am capable of doing anything I put my mind toI am capable of doing anything I put my mind to
# Yes, Thats right!
