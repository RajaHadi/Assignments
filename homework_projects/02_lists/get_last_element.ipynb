# %% [markdown]
# # **Problem Statement**
# Fill out the function get_last_element(lst) which takes in a list lst as a parameter and prints the last element in the list. The list is guaranteed to be non-empty, but there are no guarantees on its length.

# %% [markdown]
# # ***Solution:***

# %%
def get_last_elem(lst):

  print(lst[-1])

def lst_inp():


 lst = []
 elem:str=input("Enter element to add in list or press enter to close. ")
 while elem != "":
     lst.append(elem)
     elem:str=input("Enter element to add in list or press enter to close. ")
 return lst

def main():
  lst = lst_inp()
  get_last_elem(lst)

if __name__ == '__main__':
    main()
# Out:
# Enter element to add in list or press enter to close. one
# Enter element to add in list or press enter to close. bet
# Enter element to add in list or press enter to close. last
# Enter element to add in list or press enter to close.
# last
