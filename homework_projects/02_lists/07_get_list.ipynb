# %% [markdown]
# # **Problem Statement:**
# Write a program which continuously asks the user to enter values which are added one by one into a list. When the user presses enter without typing anything, print the list

# %% [markdown]
# # ***Solution***

# %%
def main():
  lst=[]
  lst_inp= input("Enter elem to add in list or press enter to close. ")
  while lst_inp != "":
    lst.append(lst_inp)
    lst_inp:str= input("Enter elem to add in list or press enter to close. ")
  print(lst)

if __name__ == '__main__':
    main()
# Out:
# Enter elem to add in list or press enter to close. chat gpt
# Enter elem to add in list or press enter to close. deep deek
# Enter elem to add in list or press enter to close. grok
# Enter elem to add in list or press enter to close. gemini
# Enter elem to add in list or press enter to close. meta
# Enter elem to add in list or press enter to close. lama
# Enter elem to add in list or press enter to close.
# ['chat gpt', 'deep deek', 'grok', 'gemini', 'meta', 'lama']
