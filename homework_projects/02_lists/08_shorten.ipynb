# %% [markdown]
# # **Problem Statement**
# Fill out the function shorten(lst) which removes elements from the end of lst, which is a list, and prints each item it removes until lst is MAX_LENGTH items long.

# %% [markdown]
# # ***Solution:***

# %%
MAX_LENGTH : int = 3

def shorten(lst):
    while len(lst) > MAX_LENGTH:
        last_elem = lst.pop()
        print(last_elem)

def get_lst():

    lst = []
    elem = input("Please enter an element of the list or press enter to stop. ")
    while elem != "":
        lst.append(elem)
        elem = input("Please enter an element of the list or press enter to stop. ")
    return lst

def main():
    lst = get_lst()
    shorten(lst)


if __name__ == '__main__':
    main()
# Out:
# Please enter an element of the list or press enter to stop. raja
# Please enter an element of the list or press enter to stop. jsj
# Please enter an element of the list or press enter to stop. lca
# Please enter an element of the list or press enter to stop. jlkl
# Please enter an element of the list or press enter to stop. sa
# Please enter an element of the list or press enter to stop.
# sa
# jlkl
