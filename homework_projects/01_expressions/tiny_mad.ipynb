# %% [markdown]
# # **Problem Statement**
# Write a program which prompts the user for an adjective, then a noun, then a verb, and then prints a fun sentence with those words!

# %%
Sentence: str = "Programming is fun. I learned to program and used Python to make my "
def main():
    adj: str = input("Please type an adjective . ")
    noun: str = input("Please type a noun . ")
    verb: str = input("Please type a verb . ")

    print(Sentence + adj + " " + noun + " " + verb + "!")

if __name__ == '__main__':
    main()
# Out:
# Please type an adjective . large
# Please type a noun . ali
# Please type a verb . going
# Programming is fun. I learned to program and used Python to make my large ali going!
