# %%
DAYS_In_Year: int = 365
HOURS_In_Day: int = 24
MIN_In_Hour: int = 60
SEC_In_Min: int = 60

def main():
       print("There are " + str(DAYS_In_Year * HOURS_In_Day * MIN_In_Hour * SEC_In_Min) + " seconds in a year!")


if __name__ == '__main__':
    main()
# Out:
# There are 31536000 seconds in a year!
