# %% [markdown]
# # **Problem Statement:**
# Converts feet to inches. Feet is an American unit of measurement. There are 12 inches per foot. Foot is the singular, and feet is the plural.

# %% [markdown]
# Solution:**bold text**

# %%
def main():
  print("Welcome, This program will convert feet into inches")
  Feet:float=float(input("Enter Feets to Convert ="))
  inches:float=Feet*12
  print(f"{Feet} feet = {inches} inches")

if __name__ == '__main__':
    main()
# Out:
# Welcome, This program will convert feet into inches
# Enter Feets to Convert20
# 20.0 feet = 240.0 inches
